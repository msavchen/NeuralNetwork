# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def gaussian(batch, stochastic=False):
    activations = batch
    if stochastic:
        return np.random.normal(activations, 1)
    else:
        return activations

def gaussian_derivative(batch):
    return np.ones_like(batch)

# %% [markdown]
# # MNIST dataset

# %%
# import mnist
# digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
# tiles(digits)

from mnist import MNIST
mnist = MNIST('la')
mnist.load_training()
mnist.load_testing()
digits = np.reshape(mnist.train_images[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    if rbm.l2_penalty is not None:
        rbm.M[:-1, :-1] = rbm.M[:-1, :-1] - rbm.learning_rate * rbm.l2_penalty * rbm.W[:-1, :-1]

    rbm.W += rbm.M;
    
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = rbm.hidden_act_func(minibatch @ rbm.W[:, :-1])
    hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size))
    
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(dbn[i].visible_act_func(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(dbn[i].hidden_act_func(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    error = reconstuction_error(dbn[layer_idx], propagated)
    return error

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

def train_dbn(dbn, dataset, monitoring_set, batch_size, epochs_count):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx))
        
        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = 0.9

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # Part 1. Autoencoder training with Nesterov accelerated gradient descend

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, l2_penalty):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.l2_penalty = l2_penalty
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ## Error backpropagation with Nesterov accelerated gradient descend
#
# __Forward pass.__ When ```compute_derivatives == false```, we are not training the network but use it to make predictions. In this case we cannot use weights in ```layer.W``` directly: in Nesterov method weights in this matrix are shifted along the direction of momentum (that is, they are at the point in the weight space where the gradient is calculated). We need to account for this when calculating the total input to the next layer.

# %%
def forward_pass(ae, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(ae):
        if not compute_derivatives:
            # We are using the network to make predictions. Fix evaluation of the total
            # input to the next layer (z) so that it uses the correct weights, and not
            # the weights where the gradient is calculated.
            z = visible @ (layer.W - layer.momentum*layer.M)
        else:
            z = visible @ layer.W
            
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(ae) - 1):
            layer.d_activations = layer.d_activation_fun(z)
            
        visible = layer.activations

    return visible[:, :-1]

# %% [markdown]
# __Backward pass.__ Implement Nesterov updates in the backward pass of error backpropagation.
#
# Remember that the weights in ```layer.W``` are shifted along the direction of momentum. Before we change the momentum matrix (but after we have everything needed to calculate the gradient), we must fix (i.e. _un-shift_) these weights.
#
# At the end of the backward pass, we must update the weight matrix accoring to the momentum interpretation of the Nesterov method.

# %%
def error_backpropagate(ae, batch):
    observations_count = batch.shape[0]

    for layer_idx, layer in reversed(list(enumerate(ae))):
        if layer_idx > 0:
            prev_layer = ae[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas @ layer.W[:-1, :].T) * prev_layer.d_activations
        else:
            visible = batch
        
        # Fix weights in layer.W before changing the momentum matrix
        layer.W -= layer.momentum*layer.M
        
        layer.M *= layer.momentum
        layer.M -= (layer.learning_rate / observations_count) * (visible.T @ layer.deltas)
        
        if layer.l2_penalty > 0:
            layer.M[:-1, :] = layer.M[:-1, :] - layer.learning_rate * layer.l2_penalty * layer.W[:-1, :]
        
        # Update the weight matrix accoring to the momentum interpretation of the Nesterov method.
        layer.W += (1 + layer.momentum) * layer.M

# %% [markdown]
# ### Cross entropy cost

# %%
def xentropy(batch, reconstructions):
    observations_count = batch.shape[0]
    loss = np.multiply(batch, np.log(reconstructions)) + np.multiply((1-batch), np.log(1-reconstructions))
    return -np.sum(loss)/observations_count

# %% [markdown]
# ### Training procedure

# %%
def train_ae(ae, dataset, batch_size): # implemented
    batches_limit = dataset.shape[0] / batch_size
    batched_data = chunks(dataset, batch_size)
    
    for batch_idx, batch in enumerate(batched_data):
        reconstructions = forward_pass(ae, batch, True)
        
        ae[-1].deltas = reconstructions - batch[:,:-1]
        
        error_backpropagate(ae, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_ae_training(ae, train_set, validation_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 10:
            for layer in ae:
                layer.momentum = 0.95
        elif epoch == 15:
            for layer in ae:
                layer.momentum = 0.97
        elif epoch == 20:
            for layer in ae:
                layer.momentum = 0.98
        elif epoch == 25:
            for layer in ae:
                layer.momentum = 0.99
        
        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print("\telapsed: {0:>2.2f}s, cross-entropy: {1:>2.2f}".format(elapsed, xe))

    print("Training finished!")

# %% [markdown]
# ###  Initializing AE with DBN weights

# %%
def initialize_ae(ae, dbn):
    assert(len(ae) == 2*len(dbn))
    for index in range(int(len(ae)/2)):
        ae[index].W = np.copy(dbn[index].W[:, :-1])
    for index in range(int(len(ae)/2), len(ae)):
        ae[index].W = np.copy(np.transpose(dbn[len(dbn)-index-1].W)[:, :-1])

# %% [markdown]
# ## Autoencoder for MNIST digits

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

#mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.array(mnist.train_images).astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

#mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.array(mnist.test_images).astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE

BATCH_SIZE = 128
EPOCHS_COUNT = 50

RBM_LEARNING_RATE = 0.1
AE_LEARNING_RATE = 0.01
AE_MOMENTUM = 0.9
L2_PENALTY = 0.0002

# %%
from IPython.core.display import HTML

def compare_results(ae, dbn,
                    train_set, validation_set, monitoring_set,
                    batch_size, epochs_count):
    for layer in ae:
        layer.reset()
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    initialize_ae(ae, dbn)
    dbn_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24, :], False),
                                     newshape=(8, 24, 28, 28))
    dbn_rec_cost = xentropy(validation_set[:, :-1],
                            forward_pass(ae, validation_set, False))
    
    display(HTML('<h3>Finetuning pretrained AE</h3>'))
    
    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_ae_training(ae, train_set, validation_set,
                    batch_size, epochs_count)
    
    display(HTML('<h3>Input minibatch</h3>'))
    tiles(np.reshape(validation_set[:8*24, :-1],
                     newshape=(8, 24, 28, 28)))
    
    display(HTML('<h3>Pretrained AE reconstructions</h3>'))
    tiles(dbn_reconstructions)
    
    display(HTML('<h3>Finetuned AE reconstructions</h3>'))
    ae_reconstructions = np.reshape(forward_pass(ae, validation_set[:8*24], False),
                                    newshape=(8, 24, 28, 28))
    tiles(ae_reconstructions)

# %% [markdown]
# ###  Autoencoder network
#
# Define the autoencoder network for MNIST digits. The network structure should be suitable for pretraining with the provided DBN.

# %%
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(64, 10, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]

ae =  [
    Layer(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
    Layer(256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY), 
    Layer(128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY), 
    Layer(64, 10, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM / 10.0, L2_PENALTY), 
    
    Layer(10, 64, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM / 10.0, L2_PENALTY),
    Layer(64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY), 
    Layer(128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY), 
    Layer(256, VISIBLE_LAYER_SIZE, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY), 
]

compare_results(ae, dbn,
                mnist_train_images, mnist_test_images,
                monitoring_set,
                BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 5.30s, reconstruction error: 31.70
# Epoch 2:	########################################	elapsed: 2.72s, reconstruction error: 24.72
# Epoch 3:	########################################	elapsed: 3.13s, reconstruction error: 21.33
# Epoch 4:	########################################	elapsed: 2.76s, reconstruction error: 18.98
# Epoch 5:	########################################	elapsed: 2.83s, reconstruction error: 17.68
# Epoch 6:	########################################	elapsed: 2.81s, reconstruction error: 15.41
# Epoch 7:	########################################	elapsed: 2.75s, reconstruction error: 13.83
# Epoch 8:	########################################	elapsed: 2.82s, reconstruction error: 12.72
# Epoch 9:	########################################	elapsed: 2.80s, reconstruction error: 12.02
# Epoch 10:	########################################	elapsed: 2.77s, reconstruction error: 11.51
# Epoch 11:	########################################	elapsed: 2.74s, reconstruction error: 11.16
# Epoch 12:	########################################	elapsed: 2.73s, reconstruction error: 10.87
# Epoch 13:	########################################	elapsed: 2.79s, reconstruction error: 10.56
# Epoch 14:	########################################	elapsed: 2.95s, reconstruction error: 10.56
# Epoch 15:	########################################	elapsed: 2.76s, reconstruction error: 10.43
# Epoch 16:	########################################	elapsed: 2.81s, reconstruction error: 10.21
# Epoch 17:	########################################	elapsed: 2.73s, reconstruction error: 10.09
# Epoch 18:	########################################	elapsed: 2.77s, reconstruction error: 9.99
# Epoch 19:	########################################	elapsed: 2.71s, reconstruction error: 9.84
# Epoch 20:	########################################	elapsed: 2.81s, reconstruction error: 9.81
# Epoch 21:	########################################	elapsed: 2.83s, reconstruction error: 9.64
# Epoch 22:	########################################	elapsed: 2.75s, reconstruction error: 9.62
# Epoch 23:	########################################	elapsed: 2.74s, reconstruction error: 9.55
# Epoch 24:	########################################	elapsed: 2.75s, reconstruction error: 9.49
# Epoch 25:	########################################	elapsed: 2.74s, reconstruction error: 9.41
# Epoch 26:	########################################	elapsed: 2.73s, reconstruction error: 9.38
# Epoch 27:	########################################	elapsed: 2.92s, reconstruction error: 9.32
# Epoch 28:	########################################	elapsed: 2.84s, reconstruction error: 9.41
# Epoch 29:	########################################	elapsed: 2.71s, reconstruction error: 9.23
# Epoch 30:	########################################	elapsed: 2.72s, reconstruction error: 9.27
# Epoch 31:	########################################	elapsed: 2.76s, reconstruction error: 9.15
# Epoch 32:	########################################	elapsed: 2.76s, reconstruction error: 9.03
# Epoch 33:	########################################	elapsed: 2.70s, reconstruction error: 9.04
# Epoch 34:	########################################	elapsed: 2.75s, reconstruction error: 8.98
# Epoch 35:	########################################	elapsed: 2.73s, reconstruction error: 9.05
# Epoch 36:	########################################	elapsed: 2.75s, reconstruction error: 8.84
# Epoch 37:	########################################	elapsed: 2.83s, reconstruction error: 8.84
# Epoch 38:	########################################	elapsed: 2.79s, reconstruction error: 8.89
# Epoch 39:	########################################	elapsed: 2.74s, reconstruction error: 9.05
# Epoch 40:	########################################	elapsed: 2.78s, reconstruction error: 8.86
# Epoch 41:	########################################	elapsed: 2.74s, reconstruction error: 8.79
# Epoch 42:	########################################	elapsed: 2.79s, reconstruction error: 8.97
# Epoch 43:	########################################	elapsed: 2.77s, reconstruction error: 8.79
# Epoch 44:	########################################	elapsed: 2.72s, reconstruction error: 8.82
# Epoch 45:	########################################	elapsed: 2.81s, reconstruction error: 8.76
# Epoch 46:	########################################	elapsed: 2.84s, reconstruction error: 8.70
# Epoch 47:	########################################	elapsed: 2.76s, reconstruction error: 8.80
# Epoch 48:	########################################	elapsed: 2.76s, reconstruction error: 8.70
# Epoch 49:	########################################	elapsed: 2.85s, reconstruction error: 8.82
# Epoch 50:	########################################	elapsed: 2.85s, reconstruction error: 8.70
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.17s, reconstruction error: 20.68
# Epoch 2:	########################################	elapsed: 1.16s, reconstruction error: 15.88
# Epoch 3:	########################################	elapsed: 1.17s, reconstruction error: 13.76
# Epoch 4:	########################################	elapsed: 1.17s, reconstruction error: 12.39
# Epoch 5:	########################################	elapsed: 1.17s, reconstruction error: 11.41
# Epoch 6:	########################################	elapsed: 1.16s, reconstruction error: 9.43
# Epoch 7:	########################################	elapsed: 1.17s, reconstruction error: 8.38
# Epoch 8:	########################################	elapsed: 1.20s, reconstruction error: 7.53
# Epoch 9:	########################################	elapsed: 1.14s, reconstruction error: 7.21
# Epoch 10:	########################################	elapsed: 1.18s, reconstruction error: 6.89
# Epoch 11:	########################################	elapsed: 1.20s, reconstruction error: 6.75
# Epoch 12:	########################################	elapsed: 1.16s, reconstruction error: 6.54
# Epoch 13:	########################################	elapsed: 1.19s, reconstruction error: 6.39
# Epoch 14:	########################################	elapsed: 1.14s, reconstruction error: 6.21
# Epoch 15:	########################################	elapsed: 1.21s, reconstruction error: 6.22
# Epoch 16:	########################################	elapsed: 1.24s, reconstruction error: 5.99
# Epoch 17:	########################################	elapsed: 1.15s, reconstruction error: 5.97
# Epoch 18:	########################################	elapsed: 1.19s, reconstruction error: 5.89
# Epoch 19:	########################################	elapsed: 1.21s, reconstruction error: 5.77
# Epoch 20:	########################################	elapsed: 1.17s, reconstruction error: 5.78
# Epoch 21:	########################################	elapsed: 1.15s, reconstruction error: 5.73
# Epoch 22:	########################################	elapsed: 1.17s, reconstruction error: 5.68
# Epoch 23:	########################################	elapsed: 1.19s, reconstruction error: 5.68
# Epoch 24:	########################################	elapsed: 1.19s, reconstruction error: 5.64
# Epoch 25:	########################################	elapsed: 1.15s, reconstruction error: 5.58
# Epoch 26:	########################################	elapsed: 1.19s, reconstruction error: 5.51
# Epoch 27:	########################################	elapsed: 1.19s, reconstruction error: 5.47
# Epoch 28:	########################################	elapsed: 1.23s, reconstruction error: 5.47
# Epoch 29:	########################################	elapsed: 1.14s, reconstruction error: 5.38
# Epoch 30:	########################################	elapsed: 1.19s, reconstruction error: 5.45
# Epoch 31:	########################################	elapsed: 1.20s, reconstruction error: 5.38
# Epoch 32:	########################################	elapsed: 1.19s, reconstruction error: 5.50
# Epoch 33:	########################################	elapsed: 1.19s, reconstruction error: 5.47
# Epoch 34:	########################################	elapsed: 1.19s, reconstruction error: 5.31
# Epoch 35:	########################################	elapsed: 1.19s, reconstruction error: 5.41
# Epoch 36:	########################################	elapsed: 1.19s, reconstruction error: 5.32
# Epoch 37:	########################################	elapsed: 1.19s, reconstruction error: 5.23
# Epoch 38:	########################################	elapsed: 1.18s, reconstruction error: 5.23
# Epoch 39:	########################################	elapsed: 1.15s, reconstruction error: 5.28
# Epoch 40:	########################################	elapsed: 1.17s, reconstruction error: 5.27
# Epoch 41:	########################################	elapsed: 1.14s, reconstruction error: 5.25
# Epoch 42:	########################################	elapsed: 1.27s, reconstruction error: 5.30
# Epoch 43:	########################################	elapsed: 1.14s, reconstruction error: 5.25
# Epoch 44:	########################################	elapsed: 1.22s, reconstruction error: 5.17
# Epoch 45:	########################################	elapsed: 1.26s, reconstruction error: 5.19
# Epoch 46:	########################################	elapsed: 1.27s, reconstruction error: 5.16
# Epoch 47:	########################################	elapsed: 1.16s, reconstruction error: 5.23
# Epoch 48:	########################################	elapsed: 1.15s, reconstruction error: 5.21
# Epoch 49:	########################################	elapsed: 1.17s, reconstruction error: 5.19
# Epoch 50:	########################################	elapsed: 1.18s, reconstruction error: 5.14
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.81s, reconstruction error: 14.36
# Epoch 2:	########################################	elapsed: 0.80s, reconstruction error: 10.72
# Epoch 3:	########################################	elapsed: 0.82s, reconstruction error: 9.20
# Epoch 4:	########################################	elapsed: 0.81s, reconstruction error: 8.17
# Epoch 5:	########################################	elapsed: 0.81s, reconstruction error: 7.59
# Epoch 6:	########################################	elapsed: 0.86s, reconstruction error: 6.26
# Epoch 7:	########################################	elapsed: 0.81s, reconstruction error: 5.61
# Epoch 8:	########################################	elapsed: 0.81s, reconstruction error: 5.17
# Epoch 9:	########################################	elapsed: 0.81s, reconstruction error: 4.94
# Epoch 10:	########################################	elapsed: 0.83s, reconstruction error: 4.85
# Epoch 11:	########################################	elapsed: 0.81s, reconstruction error: 4.75
# Epoch 12:	########################################	elapsed: 0.81s, reconstruction error: 4.65
# Epoch 13:	########################################	elapsed: 0.82s, reconstruction error: 4.53
# Epoch 14:	########################################	elapsed: 0.81s, reconstruction error: 4.54
# Epoch 15:	########################################	elapsed: 0.83s, reconstruction error: 4.49
# Epoch 16:	########################################	elapsed: 0.82s, reconstruction error: 4.41
# Epoch 17:	########################################	elapsed: 0.81s, reconstruction error: 4.39
# Epoch 18:	########################################	elapsed: 0.82s, reconstruction error: 4.35
# Epoch 19:	########################################	elapsed: 0.83s, reconstruction error: 4.32
# Epoch 20:	########################################	elapsed: 0.81s, reconstruction error: 4.27
# Epoch 21:	########################################	elapsed: 0.87s, reconstruction error: 4.28
# Epoch 22:	########################################	elapsed: 0.83s, reconstruction error: 4.30
# Epoch 23:	########################################	elapsed: 0.89s, reconstruction error: 4.29
# Epoch 24:	########################################	elapsed: 0.88s, reconstruction error: 4.18
# Epoch 25:	########################################	elapsed: 0.87s, reconstruction error: 4.28
# Epoch 26:	########################################	elapsed: 1.02s, reconstruction error: 4.17
# Epoch 27:	########################################	elapsed: 0.83s, reconstruction error: 4.18
# Epoch 28:	########################################	elapsed: 0.87s, reconstruction error: 4.14
# Epoch 29:	########################################	elapsed: 0.80s, reconstruction error: 4.14
# Epoch 30:	########################################	elapsed: 0.82s, reconstruction error: 4.11
# Epoch 31:	########################################	elapsed: 0.82s, reconstruction error: 4.10
# Epoch 32:	########################################	elapsed: 0.81s, reconstruction error: 4.14
# Epoch 33:	########################################	elapsed: 0.80s, reconstruction error: 4.06
# Epoch 34:	########################################	elapsed: 0.79s, reconstruction error: 4.08
# Epoch 35:	########################################	elapsed: 0.82s, reconstruction error: 4.05
# Epoch 36:	########################################	elapsed: 0.79s, reconstruction error: 4.09
# Epoch 37:	########################################	elapsed: 0.81s, reconstruction error: 4.05
# Epoch 38:	########################################	elapsed: 0.82s, reconstruction error: 4.03
# Epoch 39:	########################################	elapsed: 0.80s, reconstruction error: 3.98
# Epoch 40:	########################################	elapsed: 0.88s, reconstruction error: 4.01
# Epoch 41:	########################################	elapsed: 0.83s, reconstruction error: 4.06
# Epoch 42:	########################################	elapsed: 0.80s, reconstruction error: 4.00
# Epoch 43:	########################################	elapsed: 0.82s, reconstruction error: 4.10
# Epoch 44:	########################################	elapsed: 0.81s, reconstruction error: 4.03
# Epoch 45:	########################################	elapsed: 0.82s, reconstruction error: 4.03
# Epoch 46:	########################################	elapsed: 0.81s, reconstruction error: 3.94
# Epoch 47:	########################################	elapsed: 0.83s, reconstruction error: 4.00
# Epoch 48:	########################################	elapsed: 0.81s, reconstruction error: 3.97
# Epoch 49:	########################################	elapsed: 0.83s, reconstruction error: 3.99
# Epoch 50:	########################################	elapsed: 0.86s, reconstruction error: 3.98
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 0.62s, reconstruction error: 11.66
# Epoch 2:	########################################	elapsed: 0.71s, reconstruction error: 10.33
# Epoch 3:	########################################	elapsed: 0.61s, reconstruction error: 9.49
# Epoch 4:	########################################	elapsed: 0.64s, reconstruction error: 9.07
# Epoch 5:	########################################	elapsed: 0.65s, reconstruction error: 8.84
# Epoch 6:	########################################	elapsed: 0.63s, reconstruction error: 8.75
# Epoch 7:	########################################	elapsed: 0.62s, reconstruction error: 8.99
# Epoch 8:	########################################	elapsed: 0.62s, reconstruction error: 9.07
# Epoch 9:	########################################	elapsed: 0.63s, reconstruction error: 9.22
# Epoch 10:	########################################	elapsed: 0.65s, reconstruction error: 9.31
# Epoch 11:	########################################	elapsed: 0.61s, reconstruction error: 9.38
# Epoch 12:	########################################	elapsed: 0.63s, reconstruction error: 9.44
# Epoch 13:	########################################	elapsed: 0.62s, reconstruction error: 9.43
# Epoch 14:	########################################	elapsed: 0.66s, reconstruction error: 9.51
# Epoch 15:	########################################	elapsed: 0.61s, reconstruction error: 9.56
# Epoch 16:	########################################	elapsed: 0.63s, reconstruction error: 9.64
# Epoch 17:	########################################	elapsed: 0.63s, reconstruction error: 9.65
# Epoch 18:	########################################	elapsed: 0.75s, reconstruction error: 9.68
# Epoch 19:	########################################	elapsed: 0.64s, reconstruction error: 9.73
# Epoch 20:	########################################	elapsed: 0.63s, reconstruction error: 9.75
# Epoch 21:	########################################	elapsed: 0.65s, reconstruction error: 9.79
# Epoch 22:	########################################	elapsed: 0.66s, reconstruction error: 9.82
# Epoch 23:	########################################	elapsed: 0.64s, reconstruction error: 9.80
# Epoch 24:	########################################	elapsed: 0.64s, reconstruction error: 9.88
# Epoch 25:	########################################	elapsed: 0.61s, reconstruction error: 9.92
# Epoch 26:	########################################	elapsed: 0.65s, reconstruction error: 9.92
# Epoch 27:	########################################	elapsed: 0.63s, reconstruction error: 9.93
# Epoch 28:	########################################	elapsed: 0.63s, reconstruction error: 9.98
# Epoch 29:	########################################	elapsed: 0.62s, reconstruction error: 10.06
# Epoch 30:	########################################	elapsed: 0.63s, reconstruction error: 10.05
# Epoch 31:	########################################	elapsed: 0.82s, reconstruction error: 10.07
# Epoch 32:	########################################	elapsed: 0.89s, reconstruction error: 10.12
# Epoch 33:	########################################	elapsed: 0.62s, reconstruction error: 10.11
# Epoch 34:	########################################	elapsed: 0.65s, reconstruction error: 10.12
# Epoch 35:	########################################	elapsed: 0.59s, reconstruction error: 10.15
# Epoch 36:	########################################	elapsed: 0.62s, reconstruction error: 10.17
# Epoch 37:	########################################	elapsed: 0.62s, reconstruction error: 10.18
# Epoch 38:	########################################	elapsed: 0.60s, reconstruction error: 10.21
# Epoch 39:	########################################	elapsed: 0.62s, reconstruction error: 10.24
# Epoch 40:	########################################	elapsed: 0.61s, reconstruction error: 10.24
# Epoch 41:	########################################	elapsed: 0.72s, reconstruction error: 10.25
# Epoch 42:	########################################	elapsed: 0.61s, reconstruction error: 10.27
# Epoch 43:	########################################	elapsed: 0.62s, reconstruction error: 10.29
# Epoch 44:	########################################	elapsed: 0.63s, reconstruction error: 10.30
# Epoch 45:	########################################	elapsed: 0.61s, reconstruction error: 10.31
# Epoch 46:	########################################	elapsed: 0.60s, reconstruction error: 10.33
# Epoch 47:	########################################	elapsed: 0.64s, reconstruction error: 10.32
# Epoch 48:	########################################	elapsed: 0.63s, reconstruction error: 10.31
# Epoch 49:	########################################	elapsed: 0.61s, reconstruction error: 10.35
# Epoch 50:	########################################	elapsed: 0.61s, reconstruction error: 10.34
# /home/marina/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 245.91
#
# Epoch 1:	########################################	elapsed: 5.31s, cross-entropy: 245.91
# Epoch 2:	########################################	elapsed: 5.23s, cross-entropy: 245.91
# Epoch 3:	########################################	elapsed: 5.17s, cross-entropy: 245.91
# Epoch 4:	########################################	elapsed: 5.24s, cross-entropy: 245.91
# Epoch 5:	########################################	elapsed: 5.46s, cross-entropy: 245.91
# Epoch 6:	########################################	elapsed: 5.26s, cross-entropy: 245.91
# Epoch 7:	########################################	elapsed: 5.23s, cross-entropy: 245.91
# Epoch 8:	########################################	elapsed: 5.25s, cross-entropy: 245.91
# Epoch 9:	########################################	elapsed: 5.42s, cross-entropy: 245.91
# Epoch 10:	########################################	elapsed: 5.23s, cross-entropy: 245.91
# Epoch 11:	########################################	elapsed: 7.53s, cross-entropy: 252.10
# Epoch 12:	########################################	elapsed: 6.49s, cross-entropy: 252.10
# Epoch 13:	########################################	elapsed: 7.29s, cross-entropy: 252.10
# Epoch 14:	########################################	elapsed: 5.55s, cross-entropy: 252.10
# Epoch 15:	########################################	elapsed: 5.55s, cross-entropy: 252.10
# Epoch 16:	########################################	elapsed: 5.60s, cross-entropy: 253.51
# Epoch 17:	########################################	elapsed: 5.63s, cross-entropy: 253.51
# Epoch 18:	########################################	elapsed: 5.61s, cross-entropy: 253.51
# Epoch 19:	########################################	elapsed: 5.58s, cross-entropy: 253.51
# Epoch 20:	########################################	elapsed: 5.71s, cross-entropy: 253.51
# Epoch 21:	########################################	elapsed: 5.65s, cross-entropy: 254.24
# Epoch 22:	########################################	elapsed: 5.77s, cross-entropy: 254.24
# Epoch 23:	########################################	elapsed: 6.05s, cross-entropy: 254.24
# Epoch 24:	########################################	elapsed: 5.62s, cross-entropy: 254.24
# Epoch 25:	########################################	elapsed: 5.72s, cross-entropy: 254.24
# Epoch 26:	########################################	elapsed: 5.77s, cross-entropy: 254.95
# Epoch 27:	########################################	elapsed: 6.80s, cross-entropy: 254.95
# Epoch 28:	########################################	elapsed: 5.84s, cross-entropy: 254.95
# Epoch 29:	########################################	elapsed: 5.83s, cross-entropy: 254.95
# Epoch 30:	########################################	elapsed: 5.83s, cross-entropy: 254.95
# Epoch 31:	########################################	elapsed: 5.83s, cross-entropy: 254.95
# Epoch 32:	########################################	elapsed: 5.80s, cross-entropy: 254.95
# Epoch 33:	########################################	elapsed: 5.83s, cross-entropy: 254.95
# Epoch 34:	########################################	elapsed: 6.05s, cross-entropy: 254.95
# Epoch 35:	########################################	elapsed: 5.78s, cross-entropy: 254.95
# Epoch 36:	########################################	elapsed: 6.37s, cross-entropy: 254.95
# Epoch 37:	########################################	elapsed: 5.82s, cross-entropy: 254.95
# Epoch 38:	########################################	elapsed: 5.98s, cross-entropy: 254.95
# Epoch 39:	########################################	elapsed: 5.77s, cross-entropy: 254.95
# Epoch 40:	########################################	elapsed: 5.82s, cross-entropy: 254.95
# Epoch 41:	########################################	elapsed: 5.86s, cross-entropy: 254.95
# Epoch 42:	########################################	elapsed: 5.80s, cross-entropy: 254.95
# Epoch 43:	########################################	elapsed: 5.83s, cross-entropy: 254.95
# Epoch 44:	########################################	elapsed: 5.86s, cross-entropy: 254.95
# Epoch 45:	########################################	elapsed: 5.79s, cross-entropy: 254.95
# Epoch 46:	########################################	elapsed: 5.79s, cross-entropy: 254.95
# Epoch 47:	########################################	elapsed: 5.97s, cross-entropy: 254.95
# Epoch 48:	########################################	elapsed: 5.80s, cross-entropy: 254.95
# Epoch 49:	########################################	elapsed: 6.19s, cross-entropy: 254.95
# Epoch 50:	########################################	elapsed: 5.87s, cross-entropy: 254.95
# Training finished!
# <h3>Input minibatch</h3>
# <h3>Pretrained AE reconstructions</h3>
# <h3>Finetuned AE reconstructions</h3>

# %% [markdown]
# # Part 2. Visualization of MNIST digits with an autoencoder

# %%
def run_2d_ae_training(ae, train_set, validation_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 10:
            for layer in ae:
                layer.momentum = 0.8
        elif epoch == 30:
            for layer in ae:
                layer.momentum = 0.9
        
        start_time = time.time()
        train_ae(ae, train_set, batch_size)
        elapsed = time.time() - start_time

        xe = xentropy(validation_set[:, :-1], forward_pass(ae, validation_set, False))
        print("\telapsed: {0:>2.2f}s, cross-entropy: {1:>2.2f}".format(elapsed, xe))

    print("Training finished!")

# %%
def plot_2d_mnist_scatter(X, y):
    fig, plot = plt.subplots()
    fig.set_size_inches(16, 16)
    plt.prism()

    for i in range(10):
        digit_indeces = y == i
        dim1 = X[digit_indeces, 0]
        dim2 = X[digit_indeces, 1]
        plot.scatter(dim1, dim2, label=str(i))

    plot.set_xticks(())
    plot.set_yticks(())

    plt.tight_layout()
    plt.legend()
    plt.show()

# %%
from IPython.core.display import HTML

def compare_2d_visualizations(ae, dbn,
                              train_set, validation_set, validation_labels, monitoring_set,
                              batch_size, epochs_count):
    for layer in ae:
        layer.reset()
    
    display(HTML('<h3>DBN training</h3>'))
    train_dbn(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    initialize_ae(ae, dbn)
    dbn_rec_cost = xentropy(validation_set[:, :-1],
                            forward_pass(ae, validation_set, False))
    
    _ = forward_pass(ae, validation_set, False)
    dbn_codes = ae[3].activations[:, :-1]
    
    display(HTML('<h3>Finetuning pretrained AE</h3>'))
    
    print("Reconstruction cost before finetuning: {0:>2.2f}\n".format(dbn_rec_cost))
    run_2d_ae_training(ae, train_set, validation_set,
                       batch_size, epochs_count)
    
    _ = forward_pass(ae, validation_set, False)
    ae_codes = ae[3].activations[:, :-1]
    
    display(HTML('<h3>2D codes from the pretrained AE</h3>'))
    plot_2d_mnist_scatter(dbn_codes, validation_labels)
    
    display(HTML('<h3>2D codes from the finetuned AE</h3>'))
    plot_2d_mnist_scatter(ae_codes, validation_labels)

# %%
DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

#mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_images = np.array(mnist.train_images).astype(np.float32) / 255.0
mnist_train_images = np.random.permutation(mnist_train_images)

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

#mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.array(mnist.test_images).astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)
#mnist_test_labels = mnist.test_labels()
mnist_test_labels = np.array(mnist.test_labels).astype(np.float32) / 255.0

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE

BATCH_SIZE = 128
EPOCHS_COUNT = 50

RBM_LEARNING_RATE = 0.1
AE_LEARNING_RATE = 0.01
AE_MOMENTUM = 0.5
L2_PENALTY = 0.0002

# %% [markdown]
# ###  Autoencoder network for 2D visualization
#
# Define the autoencoder network for MNIST digits. Use the network structure from the previous part, but change the size of the coding layer to 2 neurons.

# %%
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(256, 128, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(128, 64, sigmoid, sigmoid, RBM_LEARNING_RATE, 0.5, L2_PENALTY),
    Rbm(64, 2, sigmoid, gaussian, RBM_LEARNING_RATE / 10.0, 0.5, L2_PENALTY)
]

ae =  [
    Layer(VISIBLE_LAYER_SIZE, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
    Layer(256, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY), 
    Layer(128, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY), 
    Layer(64, 2, gaussian, gaussian_derivative, AE_LEARNING_RATE, AE_MOMENTUM / 10.0, L2_PENALTY), 
    
    Layer(2, 64, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM / 10.0, L2_PENALTY),
    Layer(64, 128, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY), 
    Layer(128, 256, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, AE_MOMENTUM, L2_PENALTY), 
    Layer(256, VISIBLE_LAYER_SIZE, sigmoid, sigmoid_derivative, AE_LEARNING_RATE, 0.5, L2_PENALTY),
]

compare_2d_visualizations(ae, dbn,
                mnist_train_images, mnist_test_images, mnist_test_labels,
                monitoring_set,
                BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>DBN training</h3>
# Learning layer 0
# Epoch 1:	########################################	elapsed: 5.74s, reconstruction error: 23.08
# Epoch 2:	########################################	elapsed: 5.37s, reconstruction error: 17.87
# Epoch 3:	########################################	elapsed: 5.42s, reconstruction error: 15.31
# Epoch 4:	########################################	elapsed: 5.47s, reconstruction error: 14.00
# Epoch 5:	########################################	elapsed: 5.39s, reconstruction error: 13.00
# Epoch 6:	########################################	elapsed: 5.37s, reconstruction error: 12.04
# Epoch 7:	########################################	elapsed: 5.35s, reconstruction error: 10.95
# Epoch 8:	########################################	elapsed: 5.36s, reconstruction error: 10.28
# Epoch 9:	########################################	elapsed: 5.35s, reconstruction error: 9.99
# Epoch 10:	########################################	elapsed: 7.67s, reconstruction error: 9.88
# Epoch 11:	########################################	elapsed: 6.67s, reconstruction error: 9.51
# Epoch 12:	########################################	elapsed: 5.61s, reconstruction error: 9.44
# Epoch 13:	########################################	elapsed: 5.64s, reconstruction error: 9.29
# Epoch 14:	########################################	elapsed: 5.90s, reconstruction error: 9.16
# Epoch 15:	########################################	elapsed: 5.67s, reconstruction error: 9.15
# Epoch 16:	########################################	elapsed: 5.66s, reconstruction error: 8.96
# Epoch 17:	########################################	elapsed: 5.72s, reconstruction error: 8.92
# Epoch 18:	########################################	elapsed: 5.62s, reconstruction error: 8.74
# Epoch 19:	########################################	elapsed: 5.85s, reconstruction error: 8.89
# Epoch 20:	########################################	elapsed: 5.70s, reconstruction error: 8.72
# Epoch 21:	########################################	elapsed: 5.72s, reconstruction error: 8.74
# Epoch 22:	########################################	elapsed: 5.69s, reconstruction error: 8.74
# Epoch 23:	########################################	elapsed: 5.77s, reconstruction error: 8.64
# Epoch 24:	########################################	elapsed: 5.80s, reconstruction error: 8.65
# Epoch 25:	########################################	elapsed: 5.72s, reconstruction error: 8.68
# Epoch 26:	########################################	elapsed: 5.75s, reconstruction error: 8.61
# Epoch 27:	########################################	elapsed: 6.67s, reconstruction error: 8.48
# Epoch 28:	########################################	elapsed: 5.79s, reconstruction error: 8.50
# Epoch 29:	########################################	elapsed: 5.71s, reconstruction error: 8.64
# Epoch 30:	########################################	elapsed: 5.75s, reconstruction error: 8.61
# Epoch 31:	########################################	elapsed: 5.67s, reconstruction error: 8.50
# Epoch 32:	########################################	elapsed: 5.69s, reconstruction error: 8.60
# Epoch 33:	########################################	elapsed: 5.72s, reconstruction error: 8.51
# Epoch 34:	########################################	elapsed: 5.72s, reconstruction error: 8.46
# Epoch 35:	########################################	elapsed: 6.04s, reconstruction error: 8.49
# Epoch 36:	########################################	elapsed: 5.74s, reconstruction error: 8.36
# Epoch 37:	########################################	elapsed: 5.74s, reconstruction error: 8.37
# Epoch 38:	########################################	elapsed: 5.78s, reconstruction error: 8.45
# Epoch 39:	########################################	elapsed: 5.79s, reconstruction error: 8.36
# Epoch 40:	########################################	elapsed: 5.95s, reconstruction error: 8.42
# Epoch 41:	########################################	elapsed: 5.77s, reconstruction error: 8.29
# Epoch 42:	########################################	elapsed: 5.74s, reconstruction error: 8.32
# Epoch 43:	########################################	elapsed: 5.81s, reconstruction error: 8.22
# Epoch 44:	########################################	elapsed: 5.69s, reconstruction error: 8.19
# Epoch 45:	########################################	elapsed: 5.76s, reconstruction error: 8.30
# Epoch 46:	########################################	elapsed: 5.74s, reconstruction error: 8.32
# Epoch 47:	########################################	elapsed: 5.73s, reconstruction error: 8.41
# Epoch 48:	########################################	elapsed: 5.74s, reconstruction error: 8.29
# Epoch 49:	########################################	elapsed: 5.71s, reconstruction error: 8.27
# Epoch 50:	########################################	elapsed: 5.74s, reconstruction error: 8.26
#
# Learning layer 1
# Epoch 1:	########################################	elapsed: 2.48s, reconstruction error: 15.28
# Epoch 2:	########################################	elapsed: 2.46s, reconstruction error: 11.79
# Epoch 3:	########################################	elapsed: 2.44s, reconstruction error: 9.95
# Epoch 4:	########################################	elapsed: 2.48s, reconstruction error: 8.87
# Epoch 5:	########################################	elapsed: 2.43s, reconstruction error: 8.13
# Epoch 6:	########################################	elapsed: 2.46s, reconstruction error: 7.19
# Epoch 7:	########################################	elapsed: 2.45s, reconstruction error: 6.45
# Epoch 8:	########################################	elapsed: 2.44s, reconstruction error: 6.20
# Epoch 9:	########################################	elapsed: 2.53s, reconstruction error: 5.86
# Epoch 10:	########################################	elapsed: 2.51s, reconstruction error: 5.69
# Epoch 11:	########################################	elapsed: 2.82s, reconstruction error: 5.59
# Epoch 12:	########################################	elapsed: 2.73s, reconstruction error: 5.46
# Epoch 13:	########################################	elapsed: 2.58s, reconstruction error: 5.37
# Epoch 14:	########################################	elapsed: 2.45s, reconstruction error: 5.29
# Epoch 15:	########################################	elapsed: 2.46s, reconstruction error: 5.24
# Epoch 16:	########################################	elapsed: 2.47s, reconstruction error: 5.06
# Epoch 17:	########################################	elapsed: 2.45s, reconstruction error: 5.07
# Epoch 18:	########################################	elapsed: 2.54s, reconstruction error: 5.10
# Epoch 19:	########################################	elapsed: 2.43s, reconstruction error: 4.98
# Epoch 20:	########################################	elapsed: 2.56s, reconstruction error: 4.97
# Epoch 21:	########################################	elapsed: 2.45s, reconstruction error: 5.01
# Epoch 22:	########################################	elapsed: 2.47s, reconstruction error: 4.83
# Epoch 23:	########################################	elapsed: 2.73s, reconstruction error: 4.93
# Epoch 24:	########################################	elapsed: 2.56s, reconstruction error: 4.91
# Epoch 25:	########################################	elapsed: 2.46s, reconstruction error: 4.90
# Epoch 26:	########################################	elapsed: 2.48s, reconstruction error: 4.81
# Epoch 27:	########################################	elapsed: 2.54s, reconstruction error: 4.85
# Epoch 28:	########################################	elapsed: 2.57s, reconstruction error: 4.85
# Epoch 29:	########################################	elapsed: 2.62s, reconstruction error: 4.86
# Epoch 30:	########################################	elapsed: 2.53s, reconstruction error: 4.80
# Epoch 31:	########################################	elapsed: 2.52s, reconstruction error: 4.81
# Epoch 32:	########################################	elapsed: 2.58s, reconstruction error: 4.87
# Epoch 33:	########################################	elapsed: 2.48s, reconstruction error: 4.80
# Epoch 34:	########################################	elapsed: 2.51s, reconstruction error: 4.76
# Epoch 35:	########################################	elapsed: 2.52s, reconstruction error: 4.76
# Epoch 36:	########################################	elapsed: 2.47s, reconstruction error: 4.77
# Epoch 37:	########################################	elapsed: 2.53s, reconstruction error: 4.73
# Epoch 38:	########################################	elapsed: 2.63s, reconstruction error: 4.69
# Epoch 39:	########################################	elapsed: 2.37s, reconstruction error: 4.76
# Epoch 40:	########################################	elapsed: 2.32s, reconstruction error: 4.69
# Epoch 41:	########################################	elapsed: 2.34s, reconstruction error: 4.71
# Epoch 42:	########################################	elapsed: 2.35s, reconstruction error: 4.74
# Epoch 43:	########################################	elapsed: 2.40s, reconstruction error: 4.61
# Epoch 44:	########################################	elapsed: 2.36s, reconstruction error: 4.69
# Epoch 45:	########################################	elapsed: 2.38s, reconstruction error: 4.74
# Epoch 46:	########################################	elapsed: 2.43s, reconstruction error: 4.71
# Epoch 47:	########################################	elapsed: 2.38s, reconstruction error: 4.62
# Epoch 48:	########################################	elapsed: 2.49s, reconstruction error: 4.68
# Epoch 49:	########################################	elapsed: 2.42s, reconstruction error: 4.59
# Epoch 50:	########################################	elapsed: 2.44s, reconstruction error: 4.68
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 1.70s, reconstruction error: 10.49
# Epoch 2:	########################################	elapsed: 1.71s, reconstruction error: 8.09
# Epoch 3:	########################################	elapsed: 1.70s, reconstruction error: 6.84
# Epoch 4:	########################################	elapsed: 1.70s, reconstruction error: 6.13
# Epoch 5:	########################################	elapsed: 1.71s, reconstruction error: 5.73
# Epoch 6:	########################################	elapsed: 1.70s, reconstruction error: 4.96
# Epoch 7:	########################################	elapsed: 1.71s, reconstruction error: 4.63
# Epoch 8:	########################################	elapsed: 1.72s, reconstruction error: 4.39
# Epoch 9:	########################################	elapsed: 1.71s, reconstruction error: 4.26
# Epoch 10:	########################################	elapsed: 1.71s, reconstruction error: 4.18
# Epoch 11:	########################################	elapsed: 1.68s, reconstruction error: 4.12
# Epoch 12:	########################################	elapsed: 1.99s, reconstruction error: 4.03
# Epoch 13:	########################################	elapsed: 1.70s, reconstruction error: 3.98
# Epoch 14:	########################################	elapsed: 1.81s, reconstruction error: 4.00
# Epoch 15:	########################################	elapsed: 1.80s, reconstruction error: 3.97
# Epoch 16:	########################################	elapsed: 1.74s, reconstruction error: 3.91
# Epoch 17:	########################################	elapsed: 1.71s, reconstruction error: 3.90
# Epoch 18:	########################################	elapsed: 1.72s, reconstruction error: 3.89
# Epoch 19:	########################################	elapsed: 1.69s, reconstruction error: 3.87
# Epoch 20:	########################################	elapsed: 1.91s, reconstruction error: 3.87
# Epoch 21:	########################################	elapsed: 2.44s, reconstruction error: 3.84
# Epoch 22:	########################################	elapsed: 2.12s, reconstruction error: 3.84
# Epoch 23:	########################################	elapsed: 1.71s, reconstruction error: 3.79
# Epoch 24:	########################################	elapsed: 1.71s, reconstruction error: 3.80
# Epoch 25:	########################################	elapsed: 1.76s, reconstruction error: 3.80
# Epoch 26:	########################################	elapsed: 1.73s, reconstruction error: 3.79
# Epoch 27:	########################################	elapsed: 1.70s, reconstruction error: 3.82
# Epoch 28:	########################################	elapsed: 1.74s, reconstruction error: 3.72
# Epoch 29:	########################################	elapsed: 1.86s, reconstruction error: 3.77
# Epoch 30:	########################################	elapsed: 1.71s, reconstruction error: 3.77
# Epoch 31:	########################################	elapsed: 1.75s, reconstruction error: 3.74
# Epoch 32:	########################################	elapsed: 1.73s, reconstruction error: 3.76
# Epoch 33:	########################################	elapsed: 1.70s, reconstruction error: 3.78
# Epoch 34:	########################################	elapsed: 1.67s, reconstruction error: 3.79
# Epoch 35:	########################################	elapsed: 1.67s, reconstruction error: 3.81
# Epoch 36:	########################################	elapsed: 1.69s, reconstruction error: 3.72
# Epoch 37:	########################################	elapsed: 1.68s, reconstruction error: 3.70
# Epoch 38:	########################################	elapsed: 1.71s, reconstruction error: 3.72
# Epoch 39:	########################################	elapsed: 1.73s, reconstruction error: 3.70
# Epoch 40:	########################################	elapsed: 1.71s, reconstruction error: 3.71
# Epoch 41:	########################################	elapsed: 1.73s, reconstruction error: 3.71
# Epoch 42:	########################################	elapsed: 1.72s, reconstruction error: 3.71
# Epoch 43:	########################################	elapsed: 1.73s, reconstruction error: 3.69
# Epoch 44:	########################################	elapsed: 1.71s, reconstruction error: 3.65
# Epoch 45:	########################################	elapsed: 1.71s, reconstruction error: 3.65
# Epoch 46:	########################################	elapsed: 1.74s, reconstruction error: 3.72
# Epoch 47:	########################################	elapsed: 1.78s, reconstruction error: 3.67
# Epoch 48:	########################################	elapsed: 1.72s, reconstruction error: 3.63
# Epoch 49:	########################################	elapsed: 1.69s, reconstruction error: 3.68
# Epoch 50:	########################################	elapsed: 1.71s, reconstruction error: 3.70
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 1.20s, reconstruction error: 10.81
# Epoch 2:	########################################	elapsed: 1.18s, reconstruction error: 10.17
# Epoch 3:	########################################	elapsed: 1.18s, reconstruction error: 10.05
# Epoch 4:	########################################	elapsed: 1.17s, reconstruction error: 10.01
# Epoch 5:	########################################	elapsed: 1.19s, reconstruction error: 9.93
# Epoch 6:	########################################	elapsed: 1.18s, reconstruction error: 9.94
# Epoch 7:	########################################	elapsed: 1.21s, reconstruction error: 10.02
# Epoch 8:	########################################	elapsed: 1.18s, reconstruction error: 10.04
# Epoch 9:	########################################	elapsed: 1.17s, reconstruction error: 10.05
# Epoch 10:	########################################	elapsed: 1.20s, reconstruction error: 10.04
# Epoch 11:	########################################	elapsed: 1.20s, reconstruction error: 10.05
# Epoch 12:	########################################	elapsed: 1.18s, reconstruction error: 10.04
# Epoch 13:	########################################	elapsed: 1.20s, reconstruction error: 10.04
# Epoch 14:	########################################	elapsed: 1.18s, reconstruction error: 10.03
# Epoch 15:	########################################	elapsed: 1.20s, reconstruction error: 10.03
# Epoch 16:	########################################	elapsed: 1.17s, reconstruction error: 10.03
# Epoch 17:	########################################	elapsed: 1.17s, reconstruction error: 10.01
# Epoch 18:	########################################	elapsed: 1.18s, reconstruction error: 10.01
# Epoch 19:	########################################	elapsed: 1.20s, reconstruction error: 10.00
# Epoch 20:	########################################	elapsed: 1.20s, reconstruction error: 9.99
# Epoch 21:	########################################	elapsed: 1.19s, reconstruction error: 9.99
# Epoch 22:	########################################	elapsed: 1.18s, reconstruction error: 9.98
# Epoch 23:	########################################	elapsed: 1.19s, reconstruction error: 9.98
# Epoch 24:	########################################	elapsed: 1.21s, reconstruction error: 9.98
# Epoch 25:	########################################	elapsed: 1.21s, reconstruction error: 9.97
# Epoch 26:	########################################	elapsed: 1.18s, reconstruction error: 9.96
# Epoch 27:	########################################	elapsed: 1.17s, reconstruction error: 9.96
# Epoch 28:	########################################	elapsed: 1.24s, reconstruction error: 9.94
# Epoch 29:	########################################	elapsed: 1.19s, reconstruction error: 9.95
# Epoch 30:	########################################	elapsed: 1.17s, reconstruction error: 9.94
# Epoch 31:	########################################	elapsed: 1.17s, reconstruction error: 9.93
# Epoch 32:	########################################	elapsed: 1.17s, reconstruction error: 9.92
# Epoch 33:	########################################	elapsed: 1.21s, reconstruction error: 9.92
# Epoch 34:	########################################	elapsed: 1.17s, reconstruction error: 9.93
# Epoch 35:	########################################	elapsed: 1.15s, reconstruction error: 9.91
# Epoch 36:	########################################	elapsed: 1.15s, reconstruction error: 9.91
# Epoch 37:	########################################	elapsed: 1.15s, reconstruction error: 9.91
# Epoch 38:	########################################	elapsed: 1.15s, reconstruction error: 9.90
# Epoch 39:	########################################	elapsed: 1.17s, reconstruction error: 9.90
# Epoch 40:	########################################	elapsed: 1.17s, reconstruction error: 9.89
# Epoch 41:	########################################	elapsed: 1.18s, reconstruction error: 9.89
# Epoch 42:	########################################	elapsed: 1.18s, reconstruction error: 9.89
# Epoch 43:	########################################	elapsed: 1.17s, reconstruction error: 9.89
# Epoch 44:	########################################	elapsed: 1.17s, reconstruction error: 9.86
# Epoch 45:	########################################	elapsed: 1.25s, reconstruction error: 9.86
# Epoch 46:	########################################	elapsed: 1.17s, reconstruction error: 9.87
# Epoch 47:	########################################	elapsed: 1.16s, reconstruction error: 9.87
# Epoch 48:	########################################	elapsed: 1.18s, reconstruction error: 9.86
# Epoch 49:	########################################	elapsed: 1.16s, reconstruction error: 9.85
# Epoch 50:	########################################	elapsed: 1.18s, reconstruction error: 9.84
# <h3>Finetuning pretrained AE</h3>
# Reconstruction cost before finetuning: 265.07
#
# Epoch 1:	########################################	elapsed: 10.31s, cross-entropy: 265.07
# Epoch 2:	########################################	elapsed: 10.42s, cross-entropy: 265.07
# Epoch 3:	########################################	elapsed: 10.33s, cross-entropy: 265.07
# Epoch 4:	########################################	elapsed: 10.09s, cross-entropy: 265.07
# Epoch 5:	########################################	elapsed: 10.20s, cross-entropy: 265.07
# Epoch 6:	########################################	elapsed: 10.27s, cross-entropy: 265.07
# Epoch 7:	########################################	elapsed: 10.31s, cross-entropy: 265.07
# Epoch 8:	########################################	elapsed: 10.15s, cross-entropy: 265.07
# Epoch 9:	########################################	elapsed: 15.48s, cross-entropy: 265.07
# Epoch 10:	########################################	elapsed: 13.47s, cross-entropy: 265.07
# Epoch 11:	########################################	elapsed: 11.34s, cross-entropy: 272.38
# Epoch 12:	########################################	elapsed: 10.97s, cross-entropy: 272.38
# Epoch 13:	########################################	elapsed: 11.07s, cross-entropy: 272.38
# Epoch 14:	########################################	elapsed: 11.31s, cross-entropy: 272.38
# Epoch 15:	########################################	elapsed: 11.11s, cross-entropy: 272.38
# Epoch 16:	########################################	elapsed: 11.06s, cross-entropy: 272.38
# Epoch 17:	########################################	elapsed: 11.07s, cross-entropy: 272.38
# Epoch 18:	########################################	elapsed: 11.25s, cross-entropy: 272.38
# Epoch 19:	########################################	elapsed: 11.00s, cross-entropy: 272.38
# Epoch 20:	########################################	elapsed: 11.25s, cross-entropy: 272.38
# Epoch 21:	########################################	elapsed: 11.12s, cross-entropy: 272.38
# Epoch 22:	########################################	elapsed: 11.16s, cross-entropy: 272.38
# Epoch 23:	########################################	elapsed: 11.05s, cross-entropy: 272.38
# Epoch 24:	########################################	elapsed: 11.17s, cross-entropy: 272.38
# Epoch 25:	########################################	elapsed: 11.09s, cross-entropy: 272.38
# Epoch 26:	########################################	elapsed: 11.08s, cross-entropy: 272.38
# Epoch 27:	########################################	elapsed: 11.16s, cross-entropy: 272.38
# Epoch 28:	########################################	elapsed: 10.97s, cross-entropy: 272.38
# Epoch 29:	########################################	elapsed: 11.15s, cross-entropy: 272.38
# Epoch 30:	########################################	elapsed: 11.09s, cross-entropy: 272.38
# Epoch 31:	########################################	elapsed: 11.04s, cross-entropy: 276.55
# Epoch 32:	########################################	elapsed: 11.07s, cross-entropy: 276.55
# Epoch 33:	########################################	elapsed: 12.14s, cross-entropy: 276.55
# Epoch 34:	########################################	elapsed: 15.55s, cross-entropy: 276.55
# Epoch 35:	########################################	elapsed: 11.46s, cross-entropy: 276.55
# Epoch 36:	########################################	elapsed: 12.26s, cross-entropy: 276.55
# Epoch 37:	########################################	elapsed: 11.58s, cross-entropy: 276.55
# Epoch 38:	########################################	elapsed: 11.21s, cross-entropy: 276.55
# Epoch 39:	########################################	elapsed: 15.47s, cross-entropy: 276.55
# Epoch 40:	########################################	elapsed: 11.39s, cross-entropy: 276.55
# Epoch 41:	########################################	elapsed: 11.08s, cross-entropy: 276.55
# Epoch 42:	########################################	elapsed: 11.37s, cross-entropy: 276.55
# Epoch 43:	########################################	elapsed: 11.56s, cross-entropy: 276.55
# Epoch 44:	########################################	elapsed: 11.10s, cross-entropy: 276.55
# Epoch 45:	########################################	elapsed: 11.33s, cross-entropy: 276.55
# Epoch 46:	########################################	elapsed: 11.28s, cross-entropy: 276.55
# Epoch 47:	########################################	elapsed: 11.22s, cross-entropy: 276.55
# Epoch 48:	########################################	elapsed: 11.38s, cross-entropy: 276.55
# Epoch 49:	########################################	elapsed: 11.28s, cross-entropy: 276.55
# Epoch 50:	########################################	elapsed: 11.22s, cross-entropy: 276.55
# Training finished!
# <h3>2D codes from the pretrained AE</h3>
# <h3>2D codes from the finetuned AE</h3>
