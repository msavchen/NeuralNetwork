# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, pc_count = None):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.pc_count = pc_count
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.PC = None if self.pc_count is None else append_ones(zeros(self.pc_count, self.hidden_size))

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1])
    visible = sigmoid(hidden @ rbm.W.transpose()[:, :-1])
    diff = ((minibatch[:, :-1] - visible)**2)
    error = np.sum(diff)
    return error/observations_count

# %% [markdown]
# ## Algorytm Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# W sieci RBM gradient funkcji kosztu względem wag wyznaczamy zgodnie ze wzorem:
#
# $\frac{\delta}{\delta w_{ij}} -\log P(\vect{v}) = -\mathbf{E}[v_i h_j \vert \vect{v}] + \mathbf{E}[v_i h_j]$
#
# #### Faza pozytywna - odpowiada za część $\mathbf{E}[v_i h_j \vert \vect{v}]$
#
# Tą część gradientu wyznaczamy przez wyliczenie iloczynów $v_i h_j$ pomiędzy elementami wektora obserwacji ($v_i$) a prawdopodobieństwami aktywacji w warstwie ukrytej ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_P = \vect{v}^T\sigma(\vect{vW})$
#
# #### Faza negatywna - odpowiada za część $\mathbf{E}[v_i h_j]$
#
# Rozpoczynamy od prawdopodobieństw aktywacji neuronów w warstwie ukrytej, które zostały wyznaczone w fazie pozytywnej. Na ich podstawie losujemy próbkę aktywacji w warstwie ukrytej:
#
# $\vect{h} = \sigma (\vect{vW}) > [rand_1, rand_2, \dots, rand_m]$
#
# Następnie losujemy próbkę aktywacji w warstwie widocznej:
#
# $\vect{v}_1 = \sigma (\vect{hW}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Aby wyznaczyć *fantazję* sieci RBM, powyższe próbki losujemy (naprzemiennie) $k$ razy (gdzie $k$ to parametr algorytmu CD-*k*):
#
# $\vect{h}_{k-1} = \sigma (\vect{v}_{k-1}\vect{W}) > [rand_1, rand_2, \dots, rand_m]$,
# $\vect{v}_k = \sigma (\vect{h}_{k-1}\vect{W}^T) > [rand_1, rand_2, \dots, rand_n]$
#
# Część negatywną gradientu wyznaczamy poprzez wyliczenie iloczynów $v_{k_i} h_j$ pomiędzy elementami wektora *fantazji* RBM ($v_{k_i}$) a prawdopodobieństwami aktywacji w warstwie ukrytej wyliczonymi dla tejże *fantazji* ($h_j$). Operację tą możemy zapisać w postaci zwektoryzowanej jako:
#
# $\nabla_N = \vect{v}_k^T\sigma(\vect{v}_k\vect{W})$
#
#
# #### Aktualizacja macierzy wag RBM
#
# Uczymy stochastycznym spadkiem wzdłuż gradientu:
#
# $\phi_{t+1} \leftarrow \phi_t - \epsilon \nabla$
#
# co dla gradientu RBM daje:
#
# $W_{t+1} \leftarrow W_t + \epsilon \nabla_P - \epsilon \nabla_N$

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch    
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
#   faza pozytywna
    sigma_vW = sigmoid(positive_visible @ rbm.W)
    positive_hidden[:, :-1] = sigma_vW[:, :-1]  
    p = positive_visible.transpose().dot(positive_hidden)
    
#   przygotowanie punktu startu do próbkowania Gibbsa i zapisanie w negative_hidden
    tmp = rand(sigma_vW.shape[0], sigma_vW.shape[1])
    negative_hidden[:, :-1] =  (sigma_vW > tmp).astype(np.float32)[:, :-1]

    for i in range(k):
        #wyliczenie negative_visible // tu kończy się obecny krok Gibbsa
        # Następnie losujemy próbkę aktywacji w warstwie widocznej:
        sigma_hWT = sigmoid(negative_hidden.dot(rbm.W.transpose()))
        tmp = rand(sigma_hWT.shape[0], sigma_hWT.shape[1])
        
        negative_visible[:, :-1] = (sigma_hWT > tmp).astype(np.float32)[:, :-1]

        sigma_vW = sigmoid(negative_visible @ rbm.W)
        if i == k-1:
            negative_hidden[:, :-1] = sigma_vW[:, :-1]
        else:
            tmp = rand(sigma_vW.shape[0], sigma_vW.shape[1])
            negative_hidden[:, :-1] = (sigma_vW > tmp).astype(np.float32)[:, :-1]


#   wyliczenie gradientu i aktualizacja macierzy wag
    n = negative_visible.transpose().dot(negative_hidden)
    rbm.W[:, :] = rbm.W + rbm.learning_rate*((p-n)/observations_count)

# %% [markdown]
# ## Algorytm Persistent Contrastive Divergence
#
# $\newcommand{\vect}[1]{\mathbf{#1}}$
# Algorytm Persistent Contrastive Divergence (PCD) różni się od algorytmu CD przebiegiem fazy negatywnej. Faza pozytywna przebiega w PCD tak samo jak w algorytmie CD.
#
# W PCD faza negatywna rozpoczyna się od nie od przykładu uczącego, lecz od stanu *wirtualnych cząstek*, który został został zapamiętany w poprzedniej fazie negatywnej:
#
# $\vect{h} = \vect{p}$,
#
# gdzie $\vect{p}$ to macierz przechowująca stan *wirtualnych cząstek*. Po inicjalizacji negatywnego stanu ukrytego ($\vect{h}$) rozpoczynamy próbkowanie Gibbsa i wyznaczamy fantazję sieci ($\vect{v}_k$). Następnie zapamiętujemy nowy stan wirtualnych cząstek:
#
# $\vect{p} = \sigma (\vect{v}_k\vect{W}) > [rand_1, rand_2, \dots, rand_m]$.
#
# Na koniec aktualizujemy wagi RBM. Aktualizacja wag przebiega tak samo jak w algorytmie CD.

# %%
def pcd(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]
    
    positive_visible = minibatch
    negative_visible = append_ones(zeros(rbm.pc_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(rbm.pc_count, rbm.hidden_size))

        
#   faza pozytywna
    sigma_vW = sigmoid(positive_visible @ rbm.W)
    positive_hidden[:, :-1] = sigma_vW[:, :-1]  
    p = positive_visible.transpose() @ positive_hidden
    
#   przygotowanie punktu startu do próbkowania Gibbsa i zapisanie w negative_hidden
    #tmp = rand(sigma_vW.shape[0], sigma_vW.shape[1])
    negative_hidden[:, :-1] = rbm.PC[:, :-1] #(sigma_vW > tmp).astype(np.float32)[:, :-1]

    for i in range(k):
        #wyliczenie negative_visible // tu kończy się obecny krok Gibbsa
        # Następnie losujemy próbkę aktywacji w warstwie widocznej:
        sigma_hWT = sigmoid(negative_hidden.dot(rbm.W.transpose()))
        tmp = rand(sigma_hWT.shape[0], sigma_hWT.shape[1])
        
        negative_visible[:, :-1] = (sigma_hWT > tmp).astype(np.float32)[:, :-1]

        sigma_vW = sigmoid(negative_visible @ rbm.W)
        tmp = rand(sigma_vW.shape[0], sigma_vW.shape[1])
        rbm.PC[:, :-1] = (sigma_vW > tmp).astype(np.float32)[:, :-1]
        if i == k-1:
            negative_hidden[:, :-1] = sigma_vW[:, :-1]
        else:
            negative_hidden[:, :-1] = rbm.PC[:, :-1] # (sigma_vW > tmp).astype(np.float32)[:, :-1]


#   wyliczenie gradientu i aktualizacja macierzy wag
    n = negative_visible.transpose().dot(negative_hidden)
    rbm.W[:, :] = rbm.W + rbm.learning_rate*(p/observations_count-n/rbm.pc_count)

# %% [markdown]
# # RBM Training

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)
    
def draw_samples(rbm, initial_batch, steps=200):
    tiles(np.reshape(sample_rbm(rbm, initial_batch, steps)[:, :-1], (-1, 24, 28, 28)))

# %%
def train_epoch(rbm, dataset, batch_size, training_algorithm=cdk):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        training_algorithm(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count, training_algorithm=cdk):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size, training_algorithm)

        elapsed = time.time() - start_time
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %% [markdown]
# ## CDK Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

CDK_LEARNING_RATE = 0.1

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, CDK_LEARNING_RATE)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, cdk)

draw_filters(rbm)
draw_samples(rbm, monitoring_set[:10*24])
# Out:
# Epoch 0:	#######################
# /home/marina/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# ##############################	elapsed: 3.08s, reconstruction error: 30.89
# Epoch 1:	#####################################################	elapsed: 4.12s, reconstruction error: 24.51
# Epoch 2:	#####################################################	elapsed: 3.53s, reconstruction error: 20.99
# Epoch 3:	#####################################################	elapsed: 4.29s, reconstruction error: 18.80
# Epoch 4:	#####################################################	elapsed: 4.18s, reconstruction error: 17.30
# Epoch 5:	#####################################################	elapsed: 5.97s, reconstruction error: 16.26
# Epoch 6:	#####################################################	elapsed: 7.38s, reconstruction error: 15.41
# Epoch 7:	#####################################################	elapsed: 4.21s, reconstruction error: 14.63
# Epoch 8:	#####################################################	elapsed: 3.46s, reconstruction error: 14.14
# Epoch 9:	#####################################################	elapsed: 3.47s, reconstruction error: 13.57
# Epoch 10:	#####################################################	elapsed: 3.38s, reconstruction error: 13.11
# Epoch 11:	#####################################################	elapsed: 3.51s, reconstruction error: 12.77
# Epoch 12:	#####################################################	elapsed: 3.42s, reconstruction error: 12.34
# Epoch 13:	#####################################################	elapsed: 3.38s, reconstruction error: 12.09
# Epoch 14:	#####################################################	elapsed: 3.48s, reconstruction error: 11.80
# Epoch 15:	#####################################################	elapsed: 3.59s, reconstruction error: 11.54
# Epoch 16:	#####################################################	elapsed: 3.51s, reconstruction error: 11.36
# Epoch 17:	#####################################################	elapsed: 3.50s, reconstruction error: 11.18
# Epoch 18:	#####################################################	elapsed: 3.53s, reconstruction error: 10.96
# Epoch 19:	#####################################################	elapsed: 3.51s, reconstruction error: 10.82
# Epoch 20:	#####################################################	elapsed: 3.55s, reconstruction error: 10.56
# Epoch 21:	#####################################################	elapsed: 3.48s, reconstruction error: 10.49
# Epoch 22:	#####################################################	elapsed: 3.47s, reconstruction error: 10.32
# Epoch 23:	#####################################################	elapsed: 3.95s, reconstruction error: 10.18
# Epoch 24:	#####################################################	elapsed: 4.02s, reconstruction error: 10.09
# Epoch 25:	#####################################################	elapsed: 3.44s, reconstruction error: 10.00
# Epoch 26:	#####################################################	elapsed: 3.53s, reconstruction error: 9.86
# Epoch 27:	#####################################################	elapsed: 3.52s, reconstruction error: 9.79
# Epoch 28:	#####################################################	elapsed: 3.50s, reconstruction error: 9.65
# Epoch 29:	#####################################################	elapsed: 3.53s, reconstruction error: 9.62
# Epoch 30:	#####################################################	elapsed: 3.46s, reconstruction error: 9.49
# Epoch 31:	#####################################################	elapsed: 3.50s, reconstruction error: 9.40
# Epoch 32:	#####################################################	elapsed: 3.43s, reconstruction error: 9.31
# Epoch 33:	#####################################################	elapsed: 3.54s, reconstruction error: 9.25
# Epoch 34:	#####################################################	elapsed: 3.55s, reconstruction error: 9.16
# Epoch 35:	#####################################################	elapsed: 3.74s, reconstruction error: 9.09
# Epoch 36:	#####################################################	elapsed: 3.57s, reconstruction error: 9.03
# Epoch 37:	#####################################################	elapsed: 3.49s, reconstruction error: 8.96
# Epoch 38:	#####################################################	elapsed: 3.58s, reconstruction error: 8.92
# Epoch 39:	#####################################################	elapsed: 3.77s, reconstruction error: 8.88
# Epoch 40:	#####################################################	elapsed: 3.69s, reconstruction error: 8.84
# Epoch 41:	#####################################################	elapsed: 3.54s, reconstruction error: 8.71
# Epoch 42:	#####################################################	elapsed: 3.67s, reconstruction error: 8.66
# Epoch 43:	#####################################################	elapsed: 3.57s, reconstruction error: 8.67
# Epoch 44:	#####################################################	elapsed: 3.58s, reconstruction error: 8.65
# Epoch 45:	#####################################################	elapsed: 3.52s, reconstruction error: 8.55
# Epoch 46:	#####################################################	elapsed: 3.50s, reconstruction error: 8.55
# Epoch 47:	#####################################################	elapsed: 3.45s, reconstruction error: 8.52
# Epoch 48:	#####################################################	elapsed: 3.47s, reconstruction error: 8.49
# Epoch 49:	#####################################################	elapsed: 3.58s, reconstruction error: 8.42
# Training finished!

# %% [markdown]
# ## PCD Training

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

PCD_PARTICLES_COUNT = 128
PCD_LEARNING_RATE = 0.01

rbm_pcd = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, PCD_LEARNING_RATE, PCD_PARTICLES_COUNT)
draw_filters(rbm_pcd)

run_training(rbm_pcd, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT, pcd)

draw_filters(rbm_pcd)
draw_samples(rbm_pcd, monitoring_set[:10*24])
# Out:
# Epoch 0:	###############################
# /home/marina/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# ######################	elapsed: 3.88s, reconstruction error: 69.16
# Epoch 1:	#####################################################	elapsed: 3.41s, reconstruction error: 44.19
# Epoch 2:	#####################################################	elapsed: 3.63s, reconstruction error: 27.55
# Epoch 3:	#####################################################	elapsed: 4.94s, reconstruction error: 21.74
# Epoch 4:	#####################################################	elapsed: 4.64s, reconstruction error: 18.53
# Epoch 5:	#####################################################	elapsed: 3.86s, reconstruction error: 16.10
# Epoch 6:	#####################################################	elapsed: 3.56s, reconstruction error: 14.34
# Epoch 7:	#####################################################	elapsed: 3.50s, reconstruction error: 13.02
# Epoch 8:	#####################################################	elapsed: 5.44s, reconstruction error: 11.76
# Epoch 9:	#####################################################	elapsed: 7.33s, reconstruction error: 10.94
# Epoch 10:	#####################################################	elapsed: 7.02s, reconstruction error: 10.33
# Epoch 11:	#####################################################	elapsed: 6.80s, reconstruction error: 9.51
# Epoch 12:	#####################################################	elapsed: 4.15s, reconstruction error: 8.94
# Epoch 13:	#####################################################	elapsed: 4.93s, reconstruction error: 8.05
# Epoch 14:	#####################################################	elapsed: 3.55s, reconstruction error: 7.49
# Epoch 15:	#####################################################	elapsed: 6.31s, reconstruction error: 7.10
# Epoch 16:	#####################################################	elapsed: 5.22s, reconstruction error: 6.56
# Epoch 17:	#####################################################	elapsed: 4.00s, reconstruction error: 6.10
# Epoch 18:	#####################################################	elapsed: 3.94s, reconstruction error: 5.81
# Epoch 19:	#####################################################	elapsed: 4.33s, reconstruction error: 5.52
# Epoch 20:	#####################################################	elapsed: 4.49s, reconstruction error: 5.19
# Epoch 21:	#####################################################	elapsed: 3.08s, reconstruction error: 4.94
# Epoch 22:	#####################################################	elapsed: 3.17s, reconstruction error: 4.75
# Epoch 23:	#####################################################	elapsed: 3.04s, reconstruction error: 4.50
# Epoch 24:	#####################################################	elapsed: 3.09s, reconstruction error: 4.31
# Epoch 25:	#####################################################	elapsed: 3.06s, reconstruction error: 4.03
# Epoch 26:	#####################################################	elapsed: 3.05s, reconstruction error: 3.89
# Epoch 27:	#####################################################	elapsed: 3.03s, reconstruction error: 3.78
# Epoch 28:	#####################################################	elapsed: 3.04s, reconstruction error: 3.49
# Epoch 29:	#####################################################	elapsed: 3.08s, reconstruction error: 3.41
# Epoch 30:	#####################################################	elapsed: 3.04s, reconstruction error: 3.28
# Epoch 31:	#####################################################	elapsed: 3.66s, reconstruction error: 3.15
# Epoch 32:	#####################################################	elapsed: 3.03s, reconstruction error: 3.05
# Epoch 33:	#####################################################	elapsed: 2.99s, reconstruction error: 2.97
# Epoch 34:	#####################################################	elapsed: 3.25s, reconstruction error: 2.84
# Epoch 35:	#####################################################	elapsed: 3.01s, reconstruction error: 2.78
# Epoch 36:	#####################################################	elapsed: 3.01s, reconstruction error: 2.70
# Epoch 37:	#####################################################	elapsed: 2.98s, reconstruction error: 2.60
# Epoch 38:	#####################################################	elapsed: 2.98s, reconstruction error: 2.63
# Epoch 39:	#####################################################	elapsed: 2.99s, reconstruction error: 2.55
# Epoch 40:	#####################################################	elapsed: 3.01s, reconstruction error: 2.47
# Epoch 41:	#####################################################	elapsed: 3.05s, reconstruction error: 2.45
# Epoch 42:	#####################################################	elapsed: 2.98s, reconstruction error: 2.39
# Epoch 43:	#####################################################	elapsed: 2.99s, reconstruction error: 2.41
# Epoch 44:	#####################################################	elapsed: 3.02s, reconstruction error: 2.25
# Epoch 45:	#####################################################	elapsed: 3.00s, reconstruction error: 2.30
# Epoch 46:	#####################################################	elapsed: 2.99s, reconstruction error: 2.20
# Epoch 47:	#####################################################	elapsed: 3.06s, reconstruction error: 2.26
# Epoch 48:	#####################################################	elapsed: 3.00s, reconstruction error: 2.22
# Epoch 49:	#####################################################	elapsed: 3.01s, reconstruction error: 2.16
# Training finished!
