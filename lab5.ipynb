# %%
import numpy as np
import matplotlib.pyplot as plt
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # Restricted Boltzmann Machine & Contrastive Divergence algorithm

# %%
def sigmoid(matrix):
    return 1.0 / (1.0 + np.exp(-matrix))

class Rbm:
    def __init__(self, visible_size, hidden_size, learning_rate, momentum):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] = sigmoid(minibatch @ rbm.W[:, :-1])
    visible = sigmoid(hidden @ rbm.W.transpose()[:, :-1])
    diff = ((minibatch[:, :-1] - visible)**2)
    error = np.sum(diff)
    return error/observations_count

# %%
def train_epoch(rbm, dataset, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(rbm, batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

def run_training(rbm, dataset, monitoring_set, batch_size, epochs_count):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch),  end="\t")
        
        if epoch == 5:
            rbm.momentum = 0.8

        start_time = time.time()
        train_epoch(rbm, dataset, batch_size)
        elapsed = time.time() - start_time
        
        error = reconstuction_error(rbm, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

    print("Training finished!")

# %%
def draw_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# # 1. RBM Training with momentum

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch    
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
#   faza pozytywna
    sigma_vW = sigmoid(positive_visible @ rbm.W)
    positive_hidden[:, :-1] = sigma_vW[:, :-1]  
    p = positive_visible.transpose().dot(positive_hidden)
    
#   przygotowanie punktu startu do próbkowania Gibbsa i zapisanie w negative_hidden
    tmp = rand(sigma_vW.shape[0], sigma_vW.shape[1])
    negative_hidden[:, :-1] =  (sigma_vW > tmp).astype(np.float32)[:, :-1]

    for i in range(k):
        #wyliczenie negative_visible // tu kończy się obecny krok Gibbsa
        # Następnie losujemy próbkę aktywacji w warstwie widocznej:
        sigma_hWT = sigmoid(negative_hidden.dot(rbm.W.transpose()))
        tmp = rand(sigma_hWT.shape[0], sigma_hWT.shape[1])
        
        negative_visible[:, :-1] = (sigma_hWT > tmp).astype(np.float32)[:, :-1]

        sigma_vW = sigmoid(negative_visible @ rbm.W)
        if i == k-1:
            negative_hidden[:, :-1] = sigma_vW[:, :-1]
        else:
            tmp = rand(sigma_vW.shape[0], sigma_vW.shape[1])
            negative_hidden[:, :-1] = (sigma_vW > tmp).astype(np.float32)[:, :-1]


#   wyliczenie gradientu i aktualizacja macierzy wag
    n = negative_visible.transpose().dot(negative_hidden)
    grad = rbm.learning_rate*((p-n)/observations_count)
    rbm.M = rbm.momentum*rbm.M - grad
    rbm.W[:, :] = rbm.W - rbm.M

# %%
import time

DATASET_SIZE = 20000 # 60000 for whole dataset
DIGIT_SIZE = 28

VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 128

mnist_train = mnist.train_images().astype(np.float32) / 255.0
np.random.shuffle(mnist_train)
dataset = np.reshape(mnist_train[:DATASET_SIZE], newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
dataset = append_ones(dataset)

monitoring_indeces = np.random.choice(DATASET_SIZE, 256, replace=False)
monitoring_set = dataset[monitoring_indeces]

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

rbm = Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
draw_filters(rbm)

run_training(rbm, dataset, monitoring_set, BATCH_SIZE, EPOCHS_COUNT)

draw_filters(rbm)
# Out:
# Epoch 0:	##############
# /home/marina/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# #######################################	elapsed: 3.88s, reconstruction error: 25.19
# Epoch 1:	#####################################################	elapsed: 3.73s, reconstruction error: 19.48
# Epoch 2:	#####################################################	elapsed: 3.65s, reconstruction error: 16.60
# Epoch 3:	#####################################################	elapsed: 3.64s, reconstruction error: 15.00
# Epoch 4:	#####################################################	elapsed: 3.72s, reconstruction error: 13.87
# Epoch 5:	#####################################################	elapsed: 3.77s, reconstruction error: 12.63
# Epoch 6:	#####################################################	elapsed: 3.77s, reconstruction error: 11.59
# Epoch 7:	#####################################################	elapsed: 3.63s, reconstruction error: 10.85
# Epoch 8:	#####################################################	elapsed: 3.69s, reconstruction error: 10.41
# Epoch 9:	#####################################################	elapsed: 3.69s, reconstruction error: 9.95
# Epoch 10:	#####################################################	elapsed: 3.62s, reconstruction error: 9.76
# Epoch 11:	#####################################################	elapsed: 3.63s, reconstruction error: 9.50
# Epoch 12:	#####################################################	elapsed: 3.72s, reconstruction error: 9.19
# Epoch 13:	#####################################################	elapsed: 3.67s, reconstruction error: 9.03
# Epoch 14:	#####################################################	elapsed: 3.70s, reconstruction error: 8.92
# Epoch 15:	#####################################################	elapsed: 3.64s, reconstruction error: 8.81
# Epoch 16:	#####################################################	elapsed: 3.74s, reconstruction error: 8.70
# Epoch 17:	#####################################################	elapsed: 3.69s, reconstruction error: 8.66
# Epoch 18:	#####################################################	elapsed: 3.74s, reconstruction error: 8.47
# Epoch 19:	#####################################################	elapsed: 3.80s, reconstruction error: 8.41
# Epoch 20:	#####################################################	elapsed: 3.75s, reconstruction error: 8.31
# Epoch 21:	#####################################################	elapsed: 3.69s, reconstruction error: 8.24
# Epoch 22:	#####################################################	elapsed: 3.67s, reconstruction error: 8.24
# Epoch 23:	#####################################################	elapsed: 3.72s, reconstruction error: 8.20
# Epoch 24:	#####################################################	elapsed: 4.29s, reconstruction error: 8.10
# Epoch 25:	#####################################################	elapsed: 4.59s, reconstruction error: 8.15
# Epoch 26:	#####################################################	elapsed: 3.77s, reconstruction error: 8.01
# Epoch 27:	#####################################################	elapsed: 3.75s, reconstruction error: 7.94
# Epoch 28:	#####################################################	elapsed: 3.73s, reconstruction error: 7.98
# Epoch 29:	#####################################################	elapsed: 3.87s, reconstruction error: 7.92
# Epoch 30:	#####################################################	elapsed: 3.75s, reconstruction error: 7.93
# Epoch 31:	#####################################################	elapsed: 3.80s, reconstruction error: 7.88
# Epoch 32:	#####################################################	elapsed: 3.84s, reconstruction error: 7.87
# Epoch 33:	#####################################################	elapsed: 3.81s, reconstruction error: 7.73
# Epoch 34:	#####################################################	elapsed: 3.81s, reconstruction error: 7.82
# Epoch 35:	#####################################################	elapsed: 3.85s, reconstruction error: 7.75
# Epoch 36:	#####################################################	elapsed: 3.78s, reconstruction error: 7.76
# Epoch 37:	#####################################################	elapsed: 3.92s, reconstruction error: 7.70
# Epoch 38:	#####################################################	elapsed: 3.90s, reconstruction error: 7.64
# Epoch 39:	#####################################################	elapsed: 3.79s, reconstruction error: 7.61
# Epoch 40:	#####################################################	elapsed: 3.79s, reconstruction error: 7.62
# Epoch 41:	#####################################################	elapsed: 3.79s, reconstruction error: 7.61
# Epoch 42:	#####################################################	elapsed: 3.76s, reconstruction error: 7.60
# Epoch 43:	#####################################################	elapsed: 3.90s, reconstruction error: 7.62
# Epoch 44:	#####################################################	elapsed: 3.79s, reconstruction error: 7.54
# Epoch 45:	#####################################################	elapsed: 3.91s, reconstruction error: 7.55
# Epoch 46:	#####################################################	elapsed: 3.90s, reconstruction error: 7.48
# Epoch 47:	#####################################################	elapsed: 3.85s, reconstruction error: 7.57
# Epoch 48:	#####################################################	elapsed: 3.91s, reconstruction error: 7.57
# Epoch 49:	#####################################################	elapsed: 3.83s, reconstruction error: 7.55
# Training finished!

# %% [markdown]
# # 2. DBN Training

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

# %% [markdown]
# ### DBN reconstruction error

# %%
def dbn_reconstuction_error(dbn, layers_count, minibatch):    
    visible = propagate_up(dbn, layers_count, minibatch)
    return reconstuction_error(dbn[layers_count], visible)

# %% [markdown]
# ### Sampling in Deep Belief Networks

# %%
def sample_rbm(rbm, minibatch, steps):
    observations_count = minibatch.shape[0]

    visible = minibatch
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    for cd_i in range(steps):
        hidden[:, :-1] = sigmoid(visible @ rbm.W[:, :-1])
        hidden[:, :-1] = (hidden[:, :-1] > rand(observations_count, rbm.hidden_size)).astype(np.float32)
    
        visible[:, :-1] = sigmoid(hidden @ np.transpose(rbm.W[:-1, :]))
        if cd_i < (steps - 1):
            visible[:, :-1] = (visible[:, :-1] > rand(observations_count, rbm.visible_size)).astype(np.float32)

    return visible

# %%
def sample_dbn(dbn, layer_idx, minibatch, steps):
    visible = propagate_up(dbn, layer_idx, minibatch)
    visible = sample_rbm(dbn[layer_idx], visible, steps)
    hidden = propagate_down(dbn, layer_idx, visible)
    #hidden[:, :-1] = (hidden[:, :-1] > rand(hidden.shape[0], hidden.shape[1]-1)).astype(np.float32)
    return hidden

# %%
def draw_layer_samples(dbn, layer_idx, minibatch, steps=200):
    samples = sample_dbn(dbn, layer_idx, minibatch, steps)
    tiles(np.reshape(samples[:, :-1], newshape=(-1, 16, 28, 28)))

# %% [markdown]
# ### Greedy layer-wise training

# %%
def train_dbn(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)

    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 50) == 0: print("#", end="")

# %%
BATCH_SIZE = 128
EPOCHS_COUNT = 50

LEARNING_RATE = 0.1
MOMENTUM = 0.5

DBN_HIDDEN_LAYER_SIZE = 200
dbn = [
    Rbm(VISIBLE_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM),
    Rbm(DBN_HIDDEN_LAYER_SIZE, DBN_HIDDEN_LAYER_SIZE, LEARNING_RATE, MOMENTUM)
]

for layer_idx in range(len(dbn)):
    print("\nLearning layer {}".format(layer_idx))

    for epoch in range(EPOCHS_COUNT):
        print("Epoch {}:".format(epoch),  end="\t")

        if epoch == 5:
            dbn[layer_idx].momentum = 0.8
        
        start_time = time.time()
        train_dbn(dbn, layer_idx, dataset, BATCH_SIZE)
        elapsed = time.time() - start_time
        
        error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
        print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))
    
print("Training finished!")
# Out:
# Learning layer 0
# Epoch 0:	###################################
# /home/marina/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in exp
# ##################	elapsed: 4.63s, reconstruction error: 22.88
# Epoch 1:	#####################################################	elapsed: 4.61s, reconstruction error: 17.00
# Epoch 2:	#####################################################	elapsed: 4.80s, reconstruction error: 14.23
# Epoch 3:	#####################################################	elapsed: 5.04s, reconstruction error: 12.63
# Epoch 4:	#####################################################	elapsed: 5.19s, reconstruction error: 11.37
# Epoch 5:	#####################################################	elapsed: 4.69s, reconstruction error: 10.22
# Epoch 6:	#####################################################	elapsed: 4.65s, reconstruction error: 9.23
# Epoch 7:	#####################################################	elapsed: 4.76s, reconstruction error: 8.59
# Epoch 8:	#####################################################	elapsed: 4.70s, reconstruction error: 8.29
# Epoch 9:	#####################################################	elapsed: 4.61s, reconstruction error: 7.78
# Epoch 10:	#####################################################	elapsed: 4.64s, reconstruction error: 7.50
# Epoch 11:	#####################################################	elapsed: 4.62s, reconstruction error: 7.41
# Epoch 12:	#####################################################	elapsed: 4.74s, reconstruction error: 7.22
# Epoch 13:	#####################################################	elapsed: 4.68s, reconstruction error: 6.97
# Epoch 14:	#####################################################	elapsed: 5.04s, reconstruction error: 7.00
# Epoch 15:	#####################################################	elapsed: 4.67s, reconstruction error: 6.80
# Epoch 16:	#####################################################	elapsed: 4.64s, reconstruction error: 6.70
# Epoch 17:	#####################################################	elapsed: 4.68s, reconstruction error: 6.61
# Epoch 18:	#####################################################	elapsed: 4.64s, reconstruction error: 6.60
# Epoch 19:	#####################################################	elapsed: 4.63s, reconstruction error: 6.54
# Epoch 20:	#####################################################	elapsed: 4.68s, reconstruction error: 6.43
# Epoch 21:	#####################################################	elapsed: 4.81s, reconstruction error: 6.45
# Epoch 22:	#####################################################	elapsed: 4.71s, reconstruction error: 6.42
# Epoch 23:	#####################################################	elapsed: 4.77s, reconstruction error: 6.32
# Epoch 24:	#####################################################	elapsed: 4.72s, reconstruction error: 6.32
# Epoch 25:	#####################################################	elapsed: 4.79s, reconstruction error: 6.30
# Epoch 26:	#####################################################	elapsed: 4.75s, reconstruction error: 6.37
# Epoch 27:	#####################################################	elapsed: 4.78s, reconstruction error: 6.19
# Epoch 28:	#####################################################	elapsed: 4.98s, reconstruction error: 6.14
# Epoch 29:	#####################################################	elapsed: 5.39s, reconstruction error: 6.15
# Epoch 30:	#####################################################	elapsed: 4.71s, reconstruction error: 6.11
# Epoch 31:	#####################################################	elapsed: 4.78s, reconstruction error: 6.09
# Epoch 32:	#####################################################	elapsed: 4.80s, reconstruction error: 6.04
# Epoch 33:	#####################################################	elapsed: 4.80s, reconstruction error: 6.05
# Epoch 34:	#####################################################	elapsed: 4.72s, reconstruction error: 5.93
# Epoch 35:	#####################################################	elapsed: 4.85s, reconstruction error: 6.02
# Epoch 36:	#####################################################	elapsed: 4.78s, reconstruction error: 6.01
# Epoch 37:	#####################################################	elapsed: 4.83s, reconstruction error: 5.94
# Epoch 38:	#####################################################	elapsed: 8.22s, reconstruction error: 5.90
# Epoch 39:	#####################################################	elapsed: 5.67s, reconstruction error: 5.90
# Epoch 40:	#####################################################	elapsed: 4.40s, reconstruction error: 5.86
# Epoch 41:	#####################################################	elapsed: 4.71s, reconstruction error: 5.95
# Epoch 42:	#####################################################	elapsed: 4.39s, reconstruction error: 5.96
# Epoch 43:	#####################################################	elapsed: 4.39s, reconstruction error: 5.84
# Epoch 44:	#####################################################	elapsed: 4.35s, reconstruction error: 5.91
# Epoch 45:	#####################################################	elapsed: 4.28s, reconstruction error: 5.87
# Epoch 46:	#####################################################	elapsed: 4.27s, reconstruction error: 5.84
# Epoch 47:	#####################################################	elapsed: 4.26s, reconstruction error: 5.83
# Epoch 48:	#####################################################	elapsed: 4.27s, reconstruction error: 5.87
# Epoch 49:	#####################################################	elapsed: 4.31s, reconstruction error: 5.83
#
# Learning layer 1
# Epoch 0:	#####################################################	elapsed: 2.23s, reconstruction error: 13.22
# Epoch 1:	#####################################################	elapsed: 2.25s, reconstruction error: 9.25
# Epoch 2:	#####################################################	elapsed: 2.16s, reconstruction error: 7.39
# Epoch 3:	#####################################################	elapsed: 2.16s, reconstruction error: 6.21
# Epoch 4:	#####################################################	elapsed: 3.10s, reconstruction error: 5.51
# Epoch 5:	#####################################################	elapsed: 2.58s, reconstruction error: 4.75
# Epoch 6:	#####################################################	elapsed: 2.40s, reconstruction error: 4.13
# Epoch 7:	#####################################################	elapsed: 2.82s, reconstruction error: 3.80
# Epoch 8:	#####################################################	elapsed: 2.72s, reconstruction error: 3.49
# Epoch 9:	#####################################################	elapsed: 2.47s, reconstruction error: 3.19
# Epoch 10:	#####################################################	elapsed: 2.43s, reconstruction error: 3.02
# Epoch 11:	#####################################################	elapsed: 2.41s, reconstruction error: 2.92
# Epoch 12:	#####################################################	elapsed: 2.46s, reconstruction error: 2.85
# Epoch 13:	#####################################################	elapsed: 2.74s, reconstruction error: 2.74
# Epoch 14:	#####################################################	elapsed: 2.55s, reconstruction error: 2.68
# Epoch 15:	#####################################################	elapsed: 2.45s, reconstruction error: 2.63
# Epoch 16:	#####################################################	elapsed: 2.45s, reconstruction error: 2.58
# Epoch 17:	#####################################################	elapsed: 2.48s, reconstruction error: 2.50
# Epoch 18:	#####################################################	elapsed: 2.40s, reconstruction error: 2.49
# Epoch 19:	#####################################################	elapsed: 2.35s, reconstruction error: 2.48
# Epoch 20:	#####################################################	elapsed: 2.36s, reconstruction error: 2.47
# Epoch 21:	#####################################################	elapsed: 2.40s, reconstruction error: 2.40
# Epoch 22:	#####################################################	elapsed: 2.47s, reconstruction error: 2.33
# Epoch 23:	#####################################################	elapsed: 2.44s, reconstruction error: 2.36
# Epoch 24:	#####################################################	elapsed: 2.44s, reconstruction error: 2.34
# Epoch 25:	#####################################################	elapsed: 2.45s, reconstruction error: 2.27
# Epoch 26:	#####################################################	elapsed: 2.45s, reconstruction error: 2.28
# Epoch 27:	#####################################################	elapsed: 2.69s, reconstruction error: 2.24
# Epoch 28:	#####################################################	elapsed: 2.48s, reconstruction error: 2.24
# Epoch 29:	#####################################################	elapsed: 2.32s, reconstruction error: 2.23
# Epoch 30:	#####################################################	elapsed: 2.30s, reconstruction error: 2.21
# Epoch 31:	#####################################################	elapsed: 2.28s, reconstruction error: 2.22
# Epoch 32:	#####################################################	elapsed: 2.27s, reconstruction error: 2.19
# Epoch 33:	#####################################################	elapsed: 2.28s, reconstruction error: 2.16
# Epoch 34:	#####################################################	elapsed: 2.35s, reconstruction error: 2.17
# Epoch 35:	#####################################################	elapsed: 2.33s, reconstruction error: 2.19
# Epoch 36:	#####################################################	elapsed: 2.29s, reconstruction error: 2.16
# Epoch 37:	#####################################################	elapsed: 2.27s, reconstruction error: 2.15
# Epoch 38:	#####################################################	elapsed: 2.29s, reconstruction error: 2.15
# Epoch 39:	#####################################################	elapsed: 2.28s, reconstruction error: 2.14
# Epoch 40:	#####################################################	elapsed: 2.34s, reconstruction error: 2.10
# Epoch 41:	#####################################################	elapsed: 2.39s, reconstruction error: 2.11
# Epoch 42:	#####################################################	elapsed: 2.36s, reconstruction error: 2.09
# Epoch 43:	#####################################################	elapsed: 2.37s, reconstruction error: 2.13
# Epoch 44:	#####################################################	elapsed: 2.33s, reconstruction error: 2.06
# Epoch 45:	#####################################################	elapsed: 2.32s, reconstruction error: 2.09
# Epoch 46:	#####################################################	elapsed: 2.38s, reconstruction error: 2.07
# Epoch 47:	#####################################################	elapsed: 2.43s, reconstruction error: 2.04
# Epoch 48:	#####################################################	elapsed: 2.28s, reconstruction error: 2.05
# Epoch 49:	#####################################################	elapsed: 2.35s, reconstruction error: 2.07
#
# Learning layer 2
# Epoch 0:	#####################################################	elapsed: 2.61s, reconstruction error: 9.51
# Epoch 1:	#####################################################	elapsed: 2.60s, reconstruction error: 6.19
# Epoch 2:	#####################################################	elapsed: 2.64s, reconstruction error: 4.76
# Epoch 3:	#####################################################	elapsed: 2.67s, reconstruction error: 3.94
# Epoch 4:	#####################################################	elapsed: 2.64s, reconstruction error: 3.46
# Epoch 5:	#####################################################	elapsed: 2.70s, reconstruction error: 2.87
# Epoch 6:	#####################################################	elapsed: 3.26s, reconstruction error: 2.50
# Epoch 7:	#####################################################	elapsed: 2.93s, reconstruction error: 2.29
# Epoch 8:	#####################################################	elapsed: 2.72s, reconstruction error: 2.10
# Epoch 9:	#####################################################	elapsed: 2.81s, reconstruction error: 1.99
# Epoch 10:	#####################################################	elapsed: 2.67s, reconstruction error: 1.92
# Epoch 11:	#####################################################	elapsed: 2.73s, reconstruction error: 1.88
# Epoch 12:	#####################################################	elapsed: 2.71s, reconstruction error: 1.76
# Epoch 13:	#####################################################	elapsed: 2.76s, reconstruction error: 1.73
# Epoch 14:	#####################################################	elapsed: 2.88s, reconstruction error: 1.70
# Epoch 15:	#####################################################	elapsed: 2.74s, reconstruction error: 1.65
# Epoch 16:	#####################################################	elapsed: 2.74s, reconstruction error: 1.64
# Epoch 17:	#####################################################	elapsed: 2.79s, reconstruction error: 1.59
# Epoch 18:	#####################################################	elapsed: 2.92s, reconstruction error: 1.57
# Epoch 19:	#####################################################	elapsed: 2.72s, reconstruction error: 1.56
# Epoch 20:	#####################################################	elapsed: 2.83s, reconstruction error: 1.53
# Epoch 21:	#####################################################	elapsed: 2.82s, reconstruction error: 1.54
# Epoch 22:	#####################################################	elapsed: 2.72s, reconstruction error: 1.52
# Epoch 23:	#####################################################	elapsed: 2.63s, reconstruction error: 1.50
# Epoch 24:	#####################################################	elapsed: 3.88s, reconstruction error: 1.50
# Epoch 25:	#####################################################	elapsed: 3.35s, reconstruction error: 1.46
# Epoch 26:	#####################################################	elapsed: 3.20s, reconstruction error: 1.46
# Epoch 27:	#####################################################	elapsed: 3.25s, reconstruction error: 1.46
# Epoch 28:	#####################################################	elapsed: 2.80s, reconstruction error: 1.46
# Epoch 29:	#####################################################	elapsed: 2.63s, reconstruction error: 1.46
# Epoch 30:	#####################################################	elapsed: 2.62s, reconstruction error: 1.45
# Epoch 31:	#####################################################	elapsed: 2.61s, reconstruction error: 1.42
# Epoch 32:	#####################################################	elapsed: 2.69s, reconstruction error: 1.44
# Epoch 33:	#####################################################	elapsed: 3.17s, reconstruction error: 1.41
# Epoch 34:	#####################################################	elapsed: 2.63s, reconstruction error: 1.40
# Epoch 35:	#####################################################	elapsed: 2.72s, reconstruction error: 1.41
# Epoch 36:	#####################################################	elapsed: 2.74s, reconstruction error: 1.43
# Epoch 37:	#####################################################	elapsed: 2.67s, reconstruction error: 1.40
# Epoch 38:	#####################################################	elapsed: 2.66s, reconstruction error: 1.40
# Epoch 39:	#####################################################	elapsed: 2.70s, reconstruction error: 1.40
# Epoch 40:	#####################################################	elapsed: 2.67s, reconstruction error: 1.38
# Epoch 41:	#####################################################	elapsed: 2.69s, reconstruction error: 1.42
# Epoch 42:	#####################################################	elapsed: 2.67s, reconstruction error: 1.41
# Epoch 43:	#####################################################	elapsed: 2.67s, reconstruction error: 1.41
# Epoch 44:	#####################################################	elapsed: 2.68s, reconstruction error: 1.39
# Epoch 45:	#####################################################	elapsed: 2.64s, reconstruction error: 1.38
# Epoch 46:	#####################################################	elapsed: 2.69s, reconstruction error: 1.38
# Epoch 47:	#####################################################	elapsed: 2.70s, reconstruction error: 1.39
# Epoch 48:	#####################################################	elapsed: 3.21s, reconstruction error: 1.37
# Epoch 49:	#####################################################	elapsed: 3.30s, reconstruction error: 1.36
# Training finished!

# %%
draw_layer_samples(dbn, 0, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 1, monitoring_set[:8*16])

# %%
draw_layer_samples(dbn, 2, monitoring_set[:8*16])
